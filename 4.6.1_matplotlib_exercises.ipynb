# %% [markdown]
#  Use matplotlib to plot the following equation:
#
#     y = x^2 − x + 2
#
# Add an anotation for the point 0, 0, the origin.
# Note: if you call " %matplotlib notebook" instead of "%matplotlib inline" you dont need to use "plt.show" and you get some cool extra interactive features that you don't get with "%matplotlib inline",
# however , "%matplotlib inline" executes faster.  Do not include either of these % commands in a python script

# %%
#  4.6 exercises in matlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as math
x = list(range(-5,7))
y = [ (n**2 - n + 2) for n in x]
plt.plot(x,y)
# plt.annotate('(0,0)', xy=(0, 0), xytext=(0, 150), arrowprops={'facecolor': 'red'})

# %% [markdown]
# Create and label 4 separate plots for the following equations (choose a range for x that makes sense):
#
# y = √x
# y = x^3
# y = tan(x)
# y = 2^x
#
# You can use plt.figure to set the size of the plots, and hspace gives some margin between the upper and lower plots

# %%
# 4 subplots
n_rows = 2
n_cols = 2
x = list(range(0,10))
plt.figure(figsize=(7, 6)).subplots_adjust(hspace=0.4)
# sub plot 1
plt.subplot(n_rows, n_cols, 1)
y = [math.sqrt(n) for n in x]
plt.title('y = sqrt of x')
plt.plot(x, y, c='orange')
# plot 2
x = list(range(-10,10))
plt.subplot(n_rows, n_cols, 2)
y = [(n**3) for n in x]
plt.title('y = x cubed')
plt.plot(x, y, c='green')
# plot 3
x = list(range(0,10))
plt.subplot(n_rows, n_cols, 3)
y = [math.tan(n) for n in x]
plt.title('y = tangent of x')
plt.plot(x, y, c = 'red')
# plot 4
x = list(range(-10,10))
plt.subplot(n_rows, n_cols, 4)
y = [(2**n) for n in x]
plt.title('y = 2 to x power')
plt.plot(x,y, c = 'purple')
plt.suptitle('4 different functions of y(x)')
plt.show()

# %% [markdown]
# Combine 4 separate functions to single chart (choose a range for x that makes sense):
#
# y = √x
# y = x^3
# y = tan(x)
# y = 2^x

# %%
plt.figure(figsize=(7, 7))
x = list(range(1,10))
z1 = [math.sqrt(n) for n in x]
plt.plot(x, z1, c = 'orange', label='y = sqrt of x')
z2 = [(n**3) for n in x]
plt.plot(x, z2, c = 'green', label='y = x cubed')
z3 = [math.tan(n) for n in x]
plt.plot(x, z3, c = 'red', label='y = tangent of x')
z4 = [(2**n) for n in x]
plt.plot(x,z4, c = 'purple', label='y = 2 to x power')
plt.legend(loc='upper left')
plt.suptitle('Four combined functions')
plt.show()

# %% [markdown]
# Write the Python code necessary to write your name with matplotlib lines.

# %%
plt.figure(figsize=(7, 7))
lx1 = [1, 2, 3, 4, 5, 6]
ly1 = [6, 8, 8, 2, 2, 3]         
plt.plot(lx1, ly1, c='orange', label='G')
lx2 = [7, 8, 9, 10, 11]
ly2 = [2, 8, 2, 5, 5 ]
plt.plot(lx2, ly2, c='green', label='A')
lx3 = [13, 14, 15, 16, 17, 18]         
ly3 = [2, 8, 5, 5, 2, 3]
plt.plot(lx3, ly3, c = 'red', label='R')
lx4 = [19, 20, 21, 22, 23, 24]         
ly4 = [6, 8, 8, 2, 2, 3]
plt.plot(lx4,ly4, c = 'purple', label='Y')
plt.legend(loc='upper right')
plt.title('Write your name')
plt.show()
